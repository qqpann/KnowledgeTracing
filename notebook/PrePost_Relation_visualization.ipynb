# %%
import networkx as nx
# import plotly.plotly as py
# import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns

import os
import sys
import math
import pickle
import codecs
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from pathlib import Path
from math import log, ceil
from collections import defaultdict

sys.path.append('..')
from src.data import prepare_data, SOURCE_ASSIST0910_SELF, SOURCE_ASSIST0910_ORIG

# %%
def plot_relation(filename, N):
    dirname = Path().resolve()
    infname = dirname.parent / filename

    with open(infname, 'rb') as f:
        dic_skillbuilder = pickle.load(f)

    g = defaultdict(int)
    for seq in dic_skillbuilder.values():
        q = seq[0][0]
        for qa in seq[1:]:
            g[(q, qa[0])] += 1
            q = qa[0]
    g

    mat = np.zeros((N, N))

    for pos, w in g.items():
        mat[pos[0]][pos[1]] = math.log10(w)

    sns.heatmap(mat)

# %%
plot_relation('data/input/skill_builder_data_corrected.pickle', 124)

# %%
plot_relation('data/input/Asteria_Eng_ver5.pickle', 326)

# %%
plot_relation('data/input/Asteria_Eng_ver5_sorted.pickle', 326)

# %%
plot_relation('data/input/Asteria_Eng_ver5_sorted3.pickle', 326)

# %%
plot_relation('data/input/Asteria_Eng_ver5_sorted4.pickle', 326)

# %%
plot_relation('data/input/Asteria_Eng_ver5_sorted5.pickle', 326)

# %%
plot_relation('data/input/Asteria_Eng_ver5_NES.pickle', 66)

# %%
plot_relation('data/input/Asteria_Eng_ver5_NER.pickle', 47)

# %%
plot_relation('data/input/Asteria_Eng_ver5_NER.pickle', 47)

# %%
plot_relation('data/input/Asteria_Eng_ver5_NEW.pickle', 163)

# %%
plot_relation('data/input/asteria_eng_dummy.pickle', 229)
